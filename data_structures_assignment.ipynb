# %% [markdown]
# ###Task1

# %%
products = ["TV","Fridge","AC","Sofa","Table","Chair"]

# %%
sample_products = ("TV",5000,"A")

# %%
print(products[1])
print(products[-1])
# Out:
# Fridge
# Chair

# %%
products.append("Stove")
products
# Out:
# ['TV', 'Fridge', 'AC', 'Sofa', 'Table', 'Chair', 'Stove']

# %% [markdown]
# #TASK2

# %%
categories_set = {"A","B","C"}

# %%
categories_set.add("D")

# %%
"E" in categories_set
# Out:
# False

# %% [markdown]
# #TASK3

# %%
dict1 = {"TV": 5000,"Fridge": 10000,"AC": 6000,"Sofa":4000,"Table":2000,"Chair":1000}

# %%
dict1["Stove"] = 1000

# %%
dict1
# Out:
# {'TV': 5000,
#  'Fridge': 10000,
#  'AC': 6000,
#  'Sofa': 4000,
#  'Table': 2000,
#  'Chair': 1000,
#  'Stove': 1000}

# %%
dict1.pop("Sofa")
# Out:
# 4000

# %%
dict1
# Out:
# {'TV': 5000,
#  'Fridge': 10000,
#  'AC': 6000,
#  'Table': 2000,
#  'Chair': 1000,
#  'Stove': 1000}

# %%
def func (x):
    for key,values in dict1.items():
        if key == x :
            dict1.pop(x)
        else:
            break
func("Stove")
dict1
# Out:
# {'TV': 5000, 'Fridge': 10000, 'AC': 6000, 'Table': 2000, 'Chair': 1000}

# %%
sum = 0
count = 0

for key,values in dict1.items():
    sum = sum + values
    count = count+1

sum / count
# Out:
# 4800.0

# %%
largest = dict1["TV"]
smallest = dict1["TV"]
expensive = ""
cheap = ""
for key, values in dict1.items():
    if dict1[key] > largest:
        largest = dict1[key]
        expensive = key
    if dict1[key] < smallest:
        smallest = dict1[key]
        cheap = key

print(largest)
print(expensive)
print(smallest)
print(cheap)
# Out:
# 10000
# Fridge
# 1000
# Chair

# %% [markdown]
# #Task4

# %%
products = ["TV","Fridge","AC","Table","Chair"]
products
# Out:
# ['TV', 'Fridge', 'AC', 'Table', 'Chair']

# %%
dict1
# Out:
# {'TV': 5000, 'Fridge': 10000, 'AC': 6000, 'Table': 2000, 'Chair': 1000}

# %%
catalog = []
tuples=[]
for i in products:
    for key, values in dict1.items():
        if i == key:
            tuples.append(key)
            tuples.append(values)
            tuples.append("A")
            catalog.append(tuple(tuples))
            tuples = []

# %%
catalog
# Out:
# [('TV', 5000, 'A'),
#  ('Fridge', 10000, 'A'),
#  ('AC', 6000, 'A'),
#  ('Table', 2000, 'A'),
#  ('Chair', 1000, 'A')]

# %%
categories_set
# Out:
# {'A', 'B', 'C', 'D'}

# %%
dict={}
lst = []
for i in catalog:
    for j in i:
        if j in categories_set:
            lst.append(i[0])
            dict[i[2]] = lst
    

print (dict)
# Out:
# {'A': ['TV', 'Fridge', 'AC', 'Table', 'Chair']}

# %%
catalog = [('TV', 5000, 'A'),
 ('Fridge', 10000, 'A'),
 ('AC', 6000, 'B'),
 ('Table', 2000, 'A'),
 ('Chair', 1000, 'B')]

# %%
category_to_products = {}

for i in catalog:
    for j in i:
        if j in categories_set:
            if i[2] not in category_to_products:
                category_to_products[i[2]] = []
            category_to_products[i[2]].append(i[0])

print(category_to_products)
# Out:
# {'A': ['TV', 'Fridge', 'Table'], 'B': ['AC', 'Chair']}

# %%
largest = 0
for key,values in category_to_products.items():
    if len(values) > largest:
        largest = len(values)
        print(largest)
        print (values)
        print(key)
# Out:
# 3
# ['TV', 'Fridge', 'Table']
# A
